# %% [markdown]
# # Numerical Computation

# %% [markdown]
# **Overflow and underflow**
# * Underflow - numbers near zero rounded to zero
# * Overflow - larger numbers rounded to infinity
#
# **Poor conditioning**
# Matrix inversion when small changes in the matrix, radically change the inverted matrix. Rounding errors start to compound
